# %%
# !pip install pyautogui

# %%
# !pip install pyperclip

# %%
import pyautogui
import pyperclip

# %%
# configurar uma pausa entre as ações do pyautogui
pyautogui.PAUSE = 10

# abrir uma nova aba
pyautogui.hotkey("ctrl", "t")
    
# copiar o endereço do whtas para o clipboard
pyperclip.copy("https://web.whatsapp.com/")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Assaí-Check List")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 3 - Assaí")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 2 - Assaí")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 1 - Assaí")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever
pyautogui.click(x=168, y=164)


# Preenchendo o destinatário
pyperclip.copy("Atacadão-check List")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 2 - Atacadão")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)


# Preenchendo o destinatário
pyperclip.copy("GRADE 1 - Atacadão")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 3 - Atacadão")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Rede Dom - Check List")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 3 - DOM")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 2 - DOM")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 3 - DOM")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("GRADE 1 - DOM")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("CheckList - Time 4P Minas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("CheckList - Time 4P Bahia")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("CheckList - Time 4P Espírito Santo")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")    

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Check List - ROTA")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  


# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("CheckList - Time 4P Royal")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Check list - Alvo")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Agência 4P")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("ÁGUIAS - SPC & SPL")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Equipe 1 Varejo SP")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Equipe Bruna - Varejo SP")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Equipe Lucas - Varejo SP")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Equipe Líder Beto Varejo SP")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  

# clicando no botão Escrever
pyautogui.click(x=168, y=164)

# Preenchendo o destinatário
pyperclip.copy("Equipe Edson - Varejo SP")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
# Preenchendo da senha

pyperclip.copy("Bom dia Time, senha")
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1558, y=178)
pyautogui.hotkey("ctrl", "c")
pyautogui.click(x=680, y=687)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")  


# fechar a aba do whatss
pyautogui.hotkey("ctrl", "f4")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12128\1947866868.py in <module>
#      21
#      22 pyperclip.copy("Bom dia Time, senha")
# ---> 23 pyautogui.hotkey("ctrl", "v")
#      24 pyautogui.click(x=1724, y=230)
#      25 pyautogui.hotkey("ctrl", "c")
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     593         failSafeCheck()
#     594         returnVal = wrappedFunction(*args, **kwargs)
# --> 595         _handlePause(kwargs.get("_pause", True))
#     596         return returnVal
#     597
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in _handlePause(_pause)
#     637     if _pause:
#     638         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 639         time.sleep(PAUSE)
#     640
#     641
#
# KeyboardInterrupt:

# %%
import time

time.sleep(5)
pyautogui.position()
# Out:
# Point(x=168, y=164)
